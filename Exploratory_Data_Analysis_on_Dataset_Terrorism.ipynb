# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshaybajjuri012/LGMVIP/blob/main/Exploratory_Data_Analysis_on_Dataset_Terrorism.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
 data =pd.read_csv(r"/content/globalterrorismdb_0718dist.csv",  encoding='latin-1')

# %%
data
# Out:
#            eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0     197000000001   1970       7     2        NaN       0.0        NaN
# 1     197000000002   1970       0     0        NaN       0.0        NaN
# 2     197001000001   1970       1     0        NaN       0.0        NaN
# 3     197001000002   1970       1     0        NaN       0.0        NaN
# 4     197001000003   1970       1     0        NaN       0.0        NaN
# ...            ...    ...     ...   ...        ...       ...        ...
# 9651  197911130005   1979      11    13        NaN       0.0        NaN
# 9652  197911130006   1979      11    13        NaN       0.0        NaN
# 9653  197911130007   1979      11    13        NaN       0.0        NaN
# 9654  197911130008   1979      11    13        NaN       0.0        NaN
# 9655  197911140001   1979      11    14        NaN       NaN        NaN
#
#       country         country_txt  region  ... addnotes scite1 scite2  scite3  \
# 0        58.0  Dominican Republic     2.0  ...      NaN    NaN    NaN     NaN
# 1       130.0              Mexico     1.0  ...      NaN    NaN    NaN     NaN
# 2       160.0         Philippines     5.0  ...      NaN    NaN    NaN     NaN
# 3        78.0              Greece     8.0  ...      NaN    NaN    NaN     NaN
# 4       101.0               Japan     4.0  ...      NaN    NaN    NaN     NaN
# ...       ...                 ...     ...  ...      ...    ...    ...     ...
# 9651     11.0           Argentina     3.0  ...      NaN    NaN    NaN     NaN
# 9652     45.0            Colombia     3.0  ...      NaN    NaN    NaN     NaN
# 9653     45.0            Colombia     3.0  ...      NaN    NaN    NaN     NaN
# 9654    162.0            Portugal     8.0  ...      NaN    NaN    NaN     NaN
# 9655      NaN                 NaN     NaN  ...      NaN    NaN    NaN     NaN
#
#       dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0         PGIS      0.0       0.0      0.0     0.0      NaN
# 1         PGIS      0.0       1.0      1.0     1.0      NaN
# 2         PGIS     -9.0      -9.0      1.0     1.0      NaN
# 3         PGIS     -9.0      -9.0      1.0     1.0      NaN
# 4         PGIS     -9.0      -9.0      1.0     1.0      NaN
# ...        ...      ...       ...      ...     ...      ...
# 9651      PGIS      0.0       0.0      0.0     0.0      NaN
# 9652      PGIS      0.0       0.0      0.0     0.0      NaN
# 9653      PGIS      0.0       0.0      0.0     0.0      NaN
# 9654      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 9655       NaN      NaN       NaN      NaN     NaN      NaN
#
# [9656 rows x 135 columns]

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN       0.0        NaN     58.0
# 1  197000000002   1970       0     0        NaN       0.0        NaN    130.0
# 2  197001000001   1970       1     0        NaN       0.0        NaN    160.0
# 3  197001000002   1970       1     0        NaN       0.0        NaN     78.0
# 4  197001000003   1970       1     0        NaN       0.0        NaN    101.0
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic     2.0  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico     1.0  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines     5.0  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece     8.0  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan     4.0  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
data.tail()
# Out:
#            eventid  iyear  imonth  iday approxdate  extended resolution  \
# 9651  197911130005   1979      11    13        NaN       0.0        NaN
# 9652  197911130006   1979      11    13        NaN       0.0        NaN
# 9653  197911130007   1979      11    13        NaN       0.0        NaN
# 9654  197911130008   1979      11    13        NaN       0.0        NaN
# 9655  197911140001   1979      11    14        NaN       NaN        NaN
#
#       country country_txt  region  ... addnotes scite1 scite2  scite3  \
# 9651     11.0   Argentina     3.0  ...      NaN    NaN    NaN     NaN
# 9652     45.0    Colombia     3.0  ...      NaN    NaN    NaN     NaN
# 9653     45.0    Colombia     3.0  ...      NaN    NaN    NaN     NaN
# 9654    162.0    Portugal     8.0  ...      NaN    NaN    NaN     NaN
# 9655      NaN         NaN     NaN  ...      NaN    NaN    NaN     NaN
#
#       dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 9651      PGIS      0.0       0.0      0.0     0.0      NaN
# 9652      PGIS      0.0       0.0      0.0     0.0      NaN
# 9653      PGIS      0.0       0.0      0.0     0.0      NaN
# 9654      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 9655       NaN      NaN       NaN      NaN     NaN      NaN
#
# [5 rows x 135 columns]

# %%
data.describe()
# Out:
#             eventid        iyear       imonth         iday     extended  \
# count  9.656000e+03  9656.000000  9656.000000  9656.000000  9655.000000
# mean   1.976036e+11  1975.971935     6.282001    15.164561     0.026308
# std    2.889043e+08     2.890571     3.368098     9.022129     0.160057
# min    1.970000e+11  1970.000000     0.000000     0.000000     0.000000
# 25%    1.974060e+11  1974.000000     3.000000     7.000000     0.000000
# 50%    1.977060e+11  1977.000000     6.000000    15.000000     0.000000
# 75%    1.978123e+11  1978.000000     9.000000    23.000000     0.000000
# max    1.979111e+11  1979.000000    12.000000    31.000000     1.000000
#
#            country       region     latitude    longitude  specificity  ...  \
# count  9655.000000  9655.000000  9353.000000  9353.000000  9655.000000  ...
# mean    220.367892     6.021647    33.155350   -20.829568     1.203418  ...
# std     187.250876     3.289915    22.172133    53.255134     0.823601  ...
# min       4.000000     1.000000   -45.867889  -157.818968     1.000000  ...
# 25%      96.000000     2.000000    25.699073   -73.931351     1.000000  ...
# 50%     185.000000     8.000000    40.697132    -5.956210     1.000000  ...
# 75%     217.000000     8.000000    46.669097    11.119059     1.000000  ...
# max     605.000000    12.000000    64.837778   172.636225     5.000000  ...
#
#           ransomamt  ransomamtus    ransompaid  ransompaidus  hostkidoutcome  \
# count  2.820000e+02          1.0  7.900000e+01           1.0      449.000000
# mean   5.019458e+06      20000.0  1.498046e+06           0.0        2.810690
# std    5.982205e+07          NaN  5.104807e+06           NaN        1.261473
# min    0.000000e+00      20000.0  0.000000e+00           0.0        2.000000
# 25%    0.000000e+00      20000.0  6.000000e+03           0.0        2.000000
# 50%    1.200000e+04      20000.0  8.000000e+04           0.0        2.000000
# 75%    5.000000e+05      20000.0  1.000000e+06           0.0        4.000000
# max    1.000000e+09      20000.0  4.100000e+07           0.0        7.000000
#
#         nreleased      INT_LOG     INT_IDEO     INT_MISC      INT_ANY
# count  347.000000  9655.000000  9655.000000  9655.000000  9655.000000
# mean     6.345821    -3.149871    -3.096634     0.347903    -1.825893
# std     23.262047     4.430647     4.482302     0.664311     4.232378
# min    -99.000000    -9.000000    -9.000000    -9.000000    -9.000000
# 25%      1.000000    -9.000000    -9.000000     0.000000    -9.000000
# 50%      1.000000     0.000000     0.000000     0.000000     0.000000
# 75%      2.000000     0.000000     0.000000     1.000000     1.000000
# max    187.000000     1.000000     1.000000     1.000000     1.000000
#
# [8 rows x 81 columns]

# %%
data.shape
# Out:
# (9656, 135)

# %%
data.size
# Out:
# 1303560

# %%
data.ndim
# Out:
# 2

# %%
columns = data.columns.to_list()
columns
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
#  'gname3',
#  'gsubname3',
#  'motive',
#  'guncertain1',
#  'guncertain2',
#  'guncertain3',
#  'individual',
#  'nperps',
#  'nperpcap',
#  'claimed',
#  'claimmode',
#  'claimmode_txt',
#  'claim2',
#  'claimmode2',
#  'claimmode2_txt',
#  'claim3',
#  'claimmode3',
#  'claimmode3_txt',
#  'compclaim',
#  'weaptype1',
#  'weaptype1_txt',
#  'weapsubtype1',
#  'weapsubtype1_txt',
#  'weaptype2',
#  'weaptype2_txt',
#  'weapsubtype2',
#  'weapsubtype2_txt',
#  'weaptype3',
#  'weaptype3_txt',
#  'weapsubtype3',
#  'weapsubtype3_txt',
#  'weaptype4',
#  'weaptype4_txt',
#  'weapsubtype4',
#  'weapsubtype4_txt',
#  'weapdetail',
#  'nkill',
#  'nkillus',
#  'nkillter',
#  'nwound',
#  'nwoundus',
#  'nwoundte',
#  'property',
#  'propextent',
#  'propextent_txt',
#  'propvalue',
#  'propcomment',
#  'ishostkid',
#  'nhostkid',
#  'nhostkidus',
#  'nhours',
#  'ndays',
#  'divert',
#  'kidhijcountry',
#  'ransom',
#  'ransomamt',
#  'ransomamtus',
#  'ransompaid',
#  'ransompaidus',
#  'ransomnote',
#  'hostkidoutcome',
#  'hostkidoutcome_txt',
#  'nreleased',
#  'addnotes',
#  'scite1',
#  'scite2',
#  'scite3',
#  'dbsource',
#  'INT_LOG',
#  'INT_IDEO',
#  'INT_MISC',
#  'INT_ANY',
#  'related']

# %%
d1 = pd.DataFrame(data, data.rename(columns={ 'success': 'Success', 'location': 'Location', 'iyear':'Year','imonth':'Month','extended':'Extended','iday':'Day','country_txt':'Country',
                   'country': 'Country_code', 'provstate':'State','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target',
                   'nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                   'weaptype1_txt':'Weapon_type','motive':'Motive','city':'City','latitude':'Latitude','longitude':'Longitude'},inplace=True))

# %%
d1.head()
# Out:
#         eventid  Year  Month  Day approxdate  Extended resolution  \
# 0  197000000001  1970      7    2        NaN       0.0        NaN
# 1  197000000002  1970      0    0        NaN       0.0        NaN
# 2  197001000001  1970      1    0        NaN       0.0        NaN
# 3  197001000002  1970      1    0        NaN       0.0        NaN
# 4  197001000003  1970      1    0        NaN       0.0        NaN
#
#    Country_code             Country  region  ... addnotes scite1 scite2  \
# 0          58.0  Dominican Republic     2.0  ...      NaN    NaN    NaN
# 1         130.0              Mexico     1.0  ...      NaN    NaN    NaN
# 2         160.0         Philippines     5.0  ...      NaN    NaN    NaN
# 3          78.0              Greece     8.0  ...      NaN    NaN    NaN
# 4         101.0               Japan     4.0  ...      NaN    NaN    NaN
#
#    scite3  dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0     NaN      PGIS      0.0       0.0      0.0     0.0      NaN
# 1     NaN      PGIS      0.0       1.0      1.0     1.0      NaN
# 2     NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 3     NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 4     NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
d1.tail()
# Out:
#            eventid  Year  Month  Day approxdate  Extended resolution  \
# 9651  197911130005  1979     11   13        NaN       0.0        NaN
# 9652  197911130006  1979     11   13        NaN       0.0        NaN
# 9653  197911130007  1979     11   13        NaN       0.0        NaN
# 9654  197911130008  1979     11   13        NaN       0.0        NaN
# 9655  197911140001  1979     11   14        NaN       NaN        NaN
#
#       Country_code    Country  region  ... addnotes scite1 scite2  scite3  \
# 9651          11.0  Argentina     3.0  ...      NaN    NaN    NaN     NaN
# 9652          45.0   Colombia     3.0  ...      NaN    NaN    NaN     NaN
# 9653          45.0   Colombia     3.0  ...      NaN    NaN    NaN     NaN
# 9654         162.0   Portugal     8.0  ...      NaN    NaN    NaN     NaN
# 9655           NaN        NaN     NaN  ...      NaN    NaN    NaN     NaN
#
#       dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 9651      PGIS      0.0       0.0      0.0     0.0      NaN
# 9652      PGIS      0.0       0.0      0.0     0.0      NaN
# 9653      PGIS      0.0       0.0      0.0     0.0      NaN
# 9654      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 9655       NaN      NaN       NaN      NaN     NaN      NaN
#
# [5 rows x 135 columns]

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9656 entries, 0 to 9655
# Columns: 135 entries, eventid to related
# dtypes: float64(77), int64(4), object(54)
# memory usage: 9.9+ MB

# %%
d1.isnull()
# Out:
#       eventid   Year  Month    Day  approxdate  Extended  resolution  \
# 0       False  False  False  False        True     False        True
# 1       False  False  False  False        True     False        True
# 2       False  False  False  False        True     False        True
# 3       False  False  False  False        True     False        True
# 4       False  False  False  False        True     False        True
# ...       ...    ...    ...    ...         ...       ...         ...
# 9651    False  False  False  False        True     False        True
# 9652    False  False  False  False        True     False        True
# 9653    False  False  False  False        True     False        True
# 9654    False  False  False  False        True     False        True
# 9655    False  False  False  False        True      True        True
#
#       Country_code  Country  region  ...  addnotes  scite1  scite2  scite3  \
# 0            False    False   False  ...      True    True    True    True
# 1            False    False   False  ...      True    True    True    True
# 2            False    False   False  ...      True    True    True    True
# 3            False    False   False  ...      True    True    True    True
# 4            False    False   False  ...      True    True    True    True
# ...            ...      ...     ...  ...       ...     ...     ...     ...
# 9651         False    False   False  ...      True    True    True    True
# 9652         False    False   False  ...      True    True    True    True
# 9653         False    False   False  ...      True    True    True    True
# 9654         False    False   False  ...      True    True    True    True
# 9655          True     True    True  ...      True    True    True    True
#
#       dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY  related
# 0        False    False     False     False    False     True
# 1        False    False     False     False    False     True
# 2        False    False     False     False    False     True
# 3        False    False     False     False    False     True
# 4        False    False     False     False    False     True
# ...        ...      ...       ...       ...      ...      ...
# 9651     False    False     False     False    False     True
# 9652     False    False     False     False    False     True
# 9653     False    False     False     False    False     True
# 9654     False    False     False     False    False     True
# 9655      True     True      True      True     True     True
#
# [9656 rows x 135 columns]

# %%
d1.isnull().sum()
# Out:
# eventid          0
# Year             0
# Month            0
# Day              0
# approxdate    9639
#               ...
# INT_LOG          1
# INT_IDEO         1
# INT_MISC         1
# INT_ANY          1
# related       9034
# Length: 135, dtype: int64

# %%
df=d1['City'].value_counts().to_frame().drop('Unknown').sort_values('City',axis=0,ascending=False).head(10)

# %%
df.plot(kind='bar',figsize=(20,10),color='green')
plt.xticks(rotation = 50)
plt.xlabel("City",fontsize=20)
plt.ylabel("Total attacks",fontsize=20)
plt.title("Top 10 most affected cities",fontsize=25)
plt.show()

# %%
plt.subplots(figsize=(20,10))
index1=d1['Country'].value_counts()[:10].index
values1=d1['Country'].value_counts()[:10].values
sns.barplot(index1,values1,palette='rocket')
plt.title('Top 10 most affected countries', fontsize = 25)
plt.xlabel('Country', fontsize = 20)
plt.ylabel('Total attacks', fontsize = 20)
plt.xticks(rotation = 50)
plt.show()

# %%
df1=d1['Region'].value_counts().to_frame().sort_values('Region',axis=0,ascending=False).head(10)
df1.plot(kind='bar',figsize=(20,10),color='orange')
plt.xticks(rotation = 50)
plt.xlabel("Region",fontsize=20)
plt.ylabel("Total attacks",fontsize=20)
plt.title("Top 10 most affected regions",fontsize=25)
plt.show()

# %%
df2=d1[['Group','Killed']].groupby(['Group'],axis=0).sum().drop('Unknown').sort_values('Killed',ascending=False).head(10)
df2.plot(kind='bar',color='pink',figsize=(20,10))
plt.title("Top 10 terrorist attack groups",fontsize=25)
plt.xlabel("Terrorist group",fontsize=20)
plt.ylabel("Total attacks",fontsize=20)
plt.xticks(rotation=50)
plt.show()

# %%
d1['AttackType'].value_counts().plot(kind='bar',figsize=(20,10),color='red')
plt.xticks(rotation = 50)
plt.xlabel("Attack Type",fontsize=15)
plt.ylabel("Total attacks",fontsize=15)
plt.title("Most used attack types",fontsize=20)
plt.show()
